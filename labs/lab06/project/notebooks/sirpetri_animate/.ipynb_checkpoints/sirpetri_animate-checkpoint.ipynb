# %%
using DrWatson
@quickactivate "project"
include(srcdir("SIRPetri.jl"))
using .SIRPetri
using DataFrames, CSV, Plots

# %% [markdown]
# Параметры (можно оставить ваши или настроить под конкретный запуск)

# %%
β = 0.4
γ = 0.1
tmax = 50.0
# Out:
# 50.0

# %% [markdown]
# 1. Запускаем симуляцию

# %%
net, u0, _ = SIRPetri.build_sir_network(β, γ)
df = SIRPetri.simulate_deterministic(net, u0, (0.0, tmax), saveat = 0.5, rates = [β, γ])
# Out:
# 101×4 DataFrame
#  Row │ time     S             I          R
#      │ Float64  Float64       Float64    Float64
# ─────┼────────────────────────────────────────────
#    1 │     0.0  990.0          10.0        0.0
#    2 │     0.5    4.71208e-7  952.326     47.6744
#    3 │     1.0    4.84332e-7  905.88      94.1199
#    4 │     1.5   -3.35068e-7  861.7      138.3
#    5 │     2.0   -2.01894e-7  819.674    180.326
#    6 │     2.5    3.7506e-7   779.698    220.302
#    7 │     3.0   -9.70587e-8  741.672    258.328
#    8 │     3.5   -4.07287e-7  705.5      294.5
#    9 │     4.0    1.03126e-8  671.092    328.908
#   10 │     4.5    3.83756e-7  638.363    361.637
#   11 │     5.0   -3.51033e-7  607.23     392.77
#   ⋮  │    ⋮          ⋮            ⋮         ⋮
#   92 │    45.5   -5.36988e-8   10.5794   989.421
#   93 │    46.0   -1.95317e-8   10.0634   989.937
#   94 │    46.5    4.55578e-8    9.57262  990.427
#   95 │    47.0   -6.02764e-8    9.10576  990.894
#   96 │    47.5    6.20142e-8    8.66166  991.338
#   97 │    48.0   -4.78518e-8    8.23923  991.761
#   98 │    48.5    2.61214e-8    7.8374   992.163
#   99 │    49.0   -2.83712e-9    7.45516  992.545
#  100 │    49.5   -3.39885e-8    7.09157  992.908
#  101 │    50.0    6.0007e-8     6.74571  993.254
#                                    80 rows omitted

# %% [markdown]
# 2. Создаем анимацию
# Мы итерируемся по строкам DataFrame (каждый шаг времени — новый кадр)

# %%
anim = @animate for i in 1:size(df, 1)
    time_val = hasproperty(df, :t) ? df.t[i] : (hasproperty(df, :timestamp) ? df.timestamp[i] : i)
    vals = [df.S[i], df.I[i], df.R[i]]
    plot(
        ["S", "I", "R"],
        vals,
        grid = :both,
        marker = (:circle, 8, :white, stroke(2, :blue)),
        line = (:path, :blue),
        ylim = (0, maximum(df.S) * 1.1), # Автоматический предел на основе начального S
        title = "SIR dynamics at t = $(round(time_val, digits=1))",
        ylabel = "Population",
        xlabel = "Compartment",
        label = "S",
        legend = :topright
        )
end
# Out:
# Animation("/tmp/jl_Hm8Isn", ["000001.png", "000002.png", "000003.png", "000004.png", "000005.png", "000006.png", "000007.png", "000008.png", "000009.png", "000010.png"  …  "000092.png", "000093.png", "000094.png", "000095.png", "000096.png", "000097.png", "000098.png", "000099.png", "000100.png", "000101.png"])

# %% [markdown]
# 3. Сохраняем результат в gif

# %%
gif(anim, plotsdir("sir_animation.gif"), fps = 15)

println("Анимация сохранена в plots/sir_animation.gif")
# Out:
# [ Info: Saved animation to /home/nikita/work/study/2026-1/2026-1==study--simulation-modeling/2026-1--study--simulation--modeling/labs/lab06/project/plots/sir_animation.gif
# Анимация сохранена в plots/sir_animation.gif
