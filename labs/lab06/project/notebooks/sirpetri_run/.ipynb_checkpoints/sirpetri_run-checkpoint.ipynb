# %%
using Pkg
Pkg.activate("../project")
using DrWatson
@quickactivate "project"
using Random
include(srcdir("SIRPetri.jl"))
using .SIRPetri
using DataFrames, CSV, Plots
# Out:
#   Activating new project at `~/work/study/2026-1/2026-1==study--simulation-modeling/2026-1--study--simulation--modeling/labs/lab06/project/notebooks/project`
#   Activating project at `~/work/study/2026-1/2026-1==study--simulation-modeling/2026-1--study--simulation--modeling/labs/lab06/project`

# %% [markdown]
# Параметры

# %%
β = 0.3
γ = 0.1
tmax = 100.0
# Out:
# 100.0

# %% [markdown]
# Создаём сеть

# %%
net, u0, states = SIRPetri.build_sir_network(β, γ)
# Out:
# (AlgebraicPetri.LabelledPetriNet:
#   T = 1:2
#   S = 1:3
#   I = 1:3
#   O = 1:3
#   Name = 1:0
#   it : I → T = [1, 1, 2]
#   is : I → S = [1, 2, 2]
#   ot : O → T = [1, 1, 2]
#   os : O → S = [2, 2, 3]
#   tname : T → Name = [:infection, :recovery]
#   sname : S → Name = [:S, :I, :R], [990.0, 10.0, 0.0], [:S, :I, :R])

# %% [markdown]
# Детерминированная симуляция

# %%
df_det = SIRPetri.simulate_deterministic(net, u0, (0.0, tmax), saveat = 0.5, rates = [β, γ])
CSV.write(datadir("sir_det.csv"), df_det)
# Out:
# "/home/nikita/work/study/2026-1/2026-1==study--simulation-modeling/2026-1--study--simulation--modeling/labs/lab06/project/data/sir_det.csv"

# %% [markdown]
# Стохастическая симуляция

# %%
Random.seed!(123)
df_stoch = SIRPetri.simulate_stochastic(net, u0, (0.0, tmax), rates = [β, γ])
CSV.write(datadir("sir_stoch.csv"), df_stoch)
# Out:
# "/home/nikita/work/study/2026-1/2026-1==study--simulation-modeling/2026-1--study--simulation--modeling/labs/lab06/project/data/sir_stoch.csv"

# %% [markdown]
# Графики

# %%
p_det = SIRPetri.plot_sir(df_det)
savefig(plotsdir("sir_det_dynamics.png"))

p_stoch = SIRPetri.plot_sir(df_stoch)
savefig(plotsdir("sir_stoch_dynamics.png"))

println("Базовый прогон завершён. Результаты в data/ и plots/")
# Out:
# Базовый прогон завершён. Результаты в data/ и plots/
